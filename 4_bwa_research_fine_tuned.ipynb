# %%
from __future__ import annotations

import operator
import os
import re
from datetime import date, datetime, timedelta
from pathlib import Path
from typing import TypedDict, List, Optional, Literal, Annotated

from pydantic import BaseModel, Field

from langgraph.graph import StateGraph, START, END
from langgraph.types import Send

from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage, HumanMessage
from dotenv import load_dotenv
from langchain_community.tools.tavily_search import TavilySearchResults

# %%
# -----------------------------
# 1) Schemas
# -----------------------------
class Task(BaseModel):
    id: int
    title: str

    goal: str = Field(
        ...,
        description="One sentence describing what the reader should be able to do/understand after this section.",
    )
    bullets: List[str] = Field(
        ...,
        min_length=3,
        max_length=6,
        description="3–6 concrete, non-overlapping subpoints to cover in this section.",
    )
    target_words: int = Field(..., description="Target word count for this section (120–550).")

    tags: List[str] = Field(default_factory=list)
    requires_research: bool = False
    requires_citations: bool = False
    requires_code: bool = False


class Plan(BaseModel):
    blog_title: str
    audience: str
    tone: str

    # NEW: tells workers what genre this is (prevents drift)
    blog_kind: Literal["explainer", "tutorial", "news_roundup", "comparison", "system_design"] = "explainer"

    constraints: List[str] = Field(default_factory=list)
    tasks: List[Task]


class EvidenceItem(BaseModel):
    title: str
    url: str
    published_at: Optional[str] = None  # prefer ISO "YYYY-MM-DD"
    snippet: Optional[str] = None
    source: Optional[str] = None


class RouterDecision(BaseModel):
    needs_research: bool
    mode: Literal["closed_book", "hybrid", "open_book"]
    reason: str
    queries: List[str] = Field(default_factory=list)
    max_results_per_query: int = Field(5, description="How many results to fetch per query (3–8).")


class EvidencePack(BaseModel):
    evidence: List[EvidenceItem] = Field(default_factory=list)

# %%
class State(TypedDict):
    topic: str

    # routing / research
    mode: str
    needs_research: bool
    queries: List[str]
    evidence: List[EvidenceItem]
    plan: Optional[Plan]

    # NEW: recency control
    as_of: str           # ISO date, e.g. "2026-01-29"
    recency_days: int    # 7 for weekly news, 30 for hybrid, etc.

    # workers
    sections: Annotated[List[tuple[int, str]], operator.add]  # (task_id, section_md)
    final: str

# %%
# -----------------------------
# 2) LLM
# -----------------------------
from dotenv import load_dotenv
load_dotenv()
llm = ChatGroq(model="openai/gpt-oss-120b")

# %%
# -----------------------------
# 3) Router (decide upfront)
# -----------------------------
ROUTER_SYSTEM = """You are a routing module for a technical blog planner.

Decide whether web research is needed BEFORE planning.

Modes:
- closed_book (needs_research=false):
  Evergreen topics where correctness does not depend on recent facts (concepts, fundamentals).
- hybrid (needs_research=true):
  Mostly evergreen but needs up-to-date examples/tools/models to be useful.
- open_book (needs_research=true):
  Mostly volatile: weekly roundups, "this week", "latest", rankings, pricing, policy/regulation.

If needs_research=true:
- Output 3–10 high-signal queries.
- Queries should be scoped and specific (avoid generic queries like just "AI" or "LLM").
- For open_book weekly roundup, include queries that reflect the last 7 days constraint.
"""

def router_node(state: State) -> dict:
    topic = state["topic"]
    decider = llm.with_structured_output(RouterDecision)
    decision = decider.invoke(
        [
            SystemMessage(content=ROUTER_SYSTEM),
            HumanMessage(content=f"Topic: {topic}\nAs-of date: {state['as_of']}"),
        ]
    )

    # Set default recency window based on mode
    if decision.mode == "open_book":
        recency_days = 7
    elif decision.mode == "hybrid":
        recency_days = 45
    else:
        recency_days = 3650

    return {
        "needs_research": decision.needs_research,
        "mode": decision.mode,
        "queries": decision.queries,
        "recency_days": recency_days,
    }

def route_next(state: State) -> str:
    return "research" if state["needs_research"] else "orchestrator"

# %%
# -----------------------------
# 4) Research (Tavily)
# -----------------------------
def _tavily_search(query: str, max_results: int = 5) -> List[dict]:
    """
    Uses TavilySearchResults if installed and TAVILY_API_KEY is set.
    Returns list of dict with common fields. Note: published date is often missing.
    """
    tool = TavilySearchResults(max_results=max_results)
    results = tool.invoke({"query": query})

    normalized: List[dict] = []
    for r in results or []:
        normalized.append(
            {
                "title": r.get("title") or "",
                "url": r.get("url") or "",
                "snippet": r.get("content") or r.get("snippet") or "",
                "published_at": r.get("published_date") or r.get("published_at"),
                "source": r.get("source"),
            }
        )
    return normalized


def _iso_to_date(s: Optional[str]) -> Optional[date]:
    if not s:
        return None
    try:
        return date.fromisoformat(s[:10])
    except Exception:
        return None


RESEARCH_SYSTEM = """You are a research synthesizer for technical writing.

Given raw web search results, produce a deduplicated list of EvidenceItem objects.

Rules:
- Only include items with a non-empty url.
- Prefer relevant + authoritative sources (company blogs, docs, reputable outlets).
- Extract/normalize published_at as ISO (YYYY-MM-DD) if you can infer it from title/snippet.
  If you can't infer a date reliably, set published_at=null (do NOT guess).
- Keep snippets short.
- Deduplicate by URL.
"""

def research_node(state: State) -> dict:
    queries = (state.get("queries", []) or [])[:10]
    max_results = 6

    raw_results: List[dict] = []
    for q in queries:
        raw_results.extend(_tavily_search(q, max_results=max_results))

    if not raw_results:
        return {"evidence": []}

    extractor = llm.with_structured_output(EvidencePack)
    pack = extractor.invoke(
        [
            SystemMessage(content=RESEARCH_SYSTEM),
            HumanMessage(
                content=(
                    f"As-of date: {state['as_of']}\n"
                    f"Recency days: {state['recency_days']}\n\n"
                    f"Raw results:\n{raw_results}"
                )
            ),
        ]
    )

    # Deduplicate by URL
    dedup = {}
    for e in pack.evidence:
        if e.url:
            dedup[e.url] = e
    evidence = list(dedup.values())

    # HARD RECENCY FILTER for open_book weekly roundup:
    # keep only items with a parseable ISO date and within the window.
    mode = state.get("mode", "closed_book")
    if mode == "open_book":
        as_of = date.fromisoformat(state["as_of"])
        cutoff = as_of - timedelta(days=int(state["recency_days"]))
        fresh: List[EvidenceItem] = []
        for e in evidence:
            d = _iso_to_date(e.published_at)
            if d and d >= cutoff:
                fresh.append(e)
        evidence = fresh

    return {"evidence": evidence}

# %%
# -----------------------------
# 5) Orchestrator (Plan)
# -----------------------------
ORCH_SYSTEM = """You are a senior technical writer and developer advocate.
Your job is to produce a highly actionable outline for a technical blog post.

Hard requirements:
- Create 5–9 sections (tasks) suitable for the topic and audience.
- Each task must include:
  1) goal (1 sentence)
  2) 3–6 bullets that are concrete, specific, and non-overlapping
  3) target word count (120–550)

Flexibility:
- Do NOT use a fixed taxonomy unless it naturally fits.
- You may tag tasks (tags field), but tags are flexible.

Quality bar:
- Assume the reader is a developer; use correct terminology.
- Bullets must be actionable: build/compare/measure/verify/debug.
- Ensure the overall plan includes at least 2 of these somewhere:
  * minimal code sketch / MWE (set requires_code=True for that section)
  * edge cases / failure modes
  * performance/cost considerations
  * security/privacy considerations (if relevant)
  * debugging/observability tips

Grounding rules:
- Mode closed_book: keep it evergreen; do not depend on evidence.
- Mode hybrid:
  - Use evidence for up-to-date examples (models/tools/releases) in bullets.
  - Mark sections using fresh info as requires_research=True and requires_citations=True.
- Mode open_book (weekly news roundup):
  - Set blog_kind = "news_roundup".
  - Every section is about summarizing events + implications.
  - DO NOT include tutorial/how-to sections (no scraping/RSS/how to fetch news) unless user explicitly asked for that.
  - If evidence is empty or insufficient, create a plan that transparently says "insufficient fresh sources"
    and includes only what can be supported.

Output must strictly match the Plan schema.
"""

def orchestrator_node(state: State) -> dict:
    planner = llm.with_structured_output(Plan)
    evidence = state.get("evidence", [])
    mode = state.get("mode", "closed_book")

    # Force blog_kind for open_book
    forced_kind = "news_roundup" if mode == "open_book" else None

    plan = planner.invoke(
        [
            SystemMessage(content=ORCH_SYSTEM),
            HumanMessage(
                content=(
                    f"Topic: {state['topic']}\n"
                    f"Mode: {mode}\n"
                    f"As-of: {state['as_of']} (recency_days={state['recency_days']})\n"
                    f"{'Force blog_kind=news_roundup' if forced_kind else ''}\n\n"
                    f"Evidence (ONLY use for fresh claims; may be empty):\n"
                    f"{[e.model_dump() for e in evidence][:16]}\n\n"
                    f"Instruction: If mode=open_book, your plan must NOT drift into a tutorial."
                )
            ),
        ]
    )

    # Ensure open_book forces the kind even if model forgets
    if forced_kind:
        plan.blog_kind = "news_roundup"

    return {"plan": plan}


# -----------------------------
# 6) Fanout
# -----------------------------
def fanout(state: State):
    assert state["plan"] is not None
    return [
        Send(
            "worker",
            {
                "task": task.model_dump(),
                "topic": state["topic"],
                "mode": state["mode"],
                "as_of": state["as_of"],
                "recency_days": state["recency_days"],
                "plan": state["plan"].model_dump(),
                "evidence": [e.model_dump() for e in state.get("evidence", [])],
            },
        )
        for task in state["plan"].tasks
    ]

# %%
# -----------------------------
# 7) Worker (write one section)
# -----------------------------
WORKER_SYSTEM = """You are a senior technical writer and developer advocate.
Write ONE section of a technical blog post in Markdown.

Hard constraints:
- Follow the provided Goal and cover ALL Bullets in order (do not skip or merge bullets).
- Stay close to Target words (±15%).
- Output ONLY the section content in Markdown (no blog title H1, no extra commentary).
- Start with a '## <Section Title>' heading.

Scope guard (prevents mid-blog topic drift):
- If blog_kind == "news_roundup": do NOT turn this into a tutorial/how-to guide.
  Do NOT teach web scraping, RSS, automation, or "how to fetch news" unless bullets explicitly ask for it.
  Focus on summarizing events and implications.

Grounding policy:
- If mode == open_book (weekly news):
  - Do NOT introduce any specific event/company/model/funding/policy claim unless it is supported by provided Evidence URLs.
  - For each event claim, attach a source as a Markdown link: ([Source](URL)).
  - Only use URLs provided in Evidence. If not supported, write: "Not found in provided sources."
- If requires_citations == true (hybrid sections):
  - For outside-world claims, cite Evidence URLs the same way.
- Evergreen reasoning (concepts, intuition) is OK without citations unless requires_citations is true.

Code:
- If requires_code == true, include at least one minimal, correct code snippet relevant to the bullets.

Style:
- Short paragraphs, bullets where helpful, code fences for code.
- Avoid fluff/marketing. Be precise and implementation-oriented.
"""

def worker_node(payload: dict) -> dict:
    
    task = Task(**payload["task"])
    plan = Plan(**payload["plan"])
    evidence = [EvidenceItem(**e) for e in payload.get("evidence", [])]
    topic = payload["topic"]
    mode = payload.get("mode", "closed_book")
    as_of = payload.get("as_of")
    recency_days = payload.get("recency_days")

    bullets_text = "\n- " + "\n- ".join(task.bullets)

    # Provide a compact evidence list for citation use
    evidence_text = ""
    if evidence:
        evidence_text = "\n".join(
            f"- {e.title} | {e.url} | {e.published_at or 'date:unknown'}".strip()
            for e in evidence[:20]
        )

    section_md = llm.invoke(
        [
            SystemMessage(content=WORKER_SYSTEM),
            HumanMessage(
                content=(
                    f"Blog title: {plan.blog_title}\n"
                    f"Audience: {plan.audience}\n"
                    f"Tone: {plan.tone}\n"
                    f"Blog kind: {plan.blog_kind}\n"
                    f"Constraints: {plan.constraints}\n"
                    f"Topic: {topic}\n"
                    f"Mode: {mode}\n"
                    f"As-of: {as_of} (recency_days={recency_days})\n\n"
                    f"Section title: {task.title}\n"
                    f"Goal: {task.goal}\n"
                    f"Target words: {task.target_words}\n"
                    f"Tags: {task.tags}\n"
                    f"requires_research: {task.requires_research}\n"
                    f"requires_citations: {task.requires_citations}\n"
                    f"requires_code: {task.requires_code}\n"
                    f"Bullets:{bullets_text}\n\n"
                    f"Evidence (ONLY use these URLs when citing):\n{evidence_text}\n"
                )
            ),
        ]
    ).content.strip()

    # deterministic ordering
    return {"sections": [(task.id, section_md)]}

# %%
# -----------------------------
# 8) Reducer (merge + save)
# -----------------------------
def reducer_node(state: State) -> dict:
    plan = state["plan"]
    if plan is None:
        raise ValueError("Reducer called without a plan.")

    ordered_sections = [md for _, md in sorted(state["sections"], key=lambda x: x[0])]
    body = "\n\n".join(ordered_sections).strip()
    final_md = f"# {plan.blog_title}\n\n{body}\n"

    filename = f"{plan.blog_title}.md"
    Path(filename).write_text(final_md, encoding="utf-8")

    return {"final": final_md}

# %%
# -----------------------------
# 9) Build graph
# -----------------------------
g = StateGraph(State)
g.add_node("router", router_node)
g.add_node("research", research_node)
g.add_node("orchestrator", orchestrator_node)
g.add_node("worker", worker_node)
g.add_node("reducer", reducer_node)

g.add_edge(START, "router")
g.add_conditional_edges("router", route_next, {"research": "research", "orchestrator": "orchestrator"})
g.add_edge("research", "orchestrator")

g.add_conditional_edges("orchestrator", fanout, ["worker"])
g.add_edge("worker", "reducer")
g.add_edge("reducer", END)

app = g.compile()

app

# %%
# -----------------------------
# 10) Runner
# -----------------------------
def run(topic: str, as_of: Optional[str] = None):
    if as_of is None:
        as_of = date.today().isoformat()

    out = app.invoke(
        {
            "topic": topic,
            "mode": "",
            "needs_research": False,
            "queries": [],
            "evidence": [],
            "plan": None,
            "as_of": as_of,
            "recency_days": 7,   # router may overwrite
            "sections": [],
            "final": "",
        }
    )

    plan: Plan = out["plan"]
    print("\n" + "=" * 100)
    print("TOPIC:", topic)
    print("AS_OF:", out.get("as_of"), "RECENCY_DAYS:", out.get("recency_days"))
    print("MODE:", out.get("mode"))
    print("BLOG_KIND:", plan.blog_kind)
    print("NEEDS_RESEARCH:", out.get("needs_research"))
    print("QUERIES:", (out.get("queries") or [])[:6])
    print("EVIDENCE_COUNT:", len(out.get("evidence", [])))
    if out.get("evidence"):
        print("EVIDENCE_SAMPLE:", [e.model_dump() for e in out["evidence"][:2]])
    print("TASKS:", len(plan.tasks))
    print("SAVED_MD_CHARS:", len(out.get("final", "")))
    print("=" * 100 + "\n")

    return out

# %%
run("Write a blog on Self Attention")
# Out:
# ====================================================================================================
# TOPIC: Write a blog on Self Attention
# AS_OF: 2026-02-09 RECENCY_DAYS: 3650
# MODE: closed_book
# BLOG_KIND: explainer
# NEEDS_RESEARCH: False
# QUERIES: []
# EVIDENCE_COUNT: 0
# TASKS: 6
# SAVED_MD_CHARS: 18841
# ====================================================================================================
# {'topic': 'Write a blog on Self Attention',
#  'mode': 'closed_book',
#  'needs_research': False,
#  'queries': [],
#  'evidence': [],
#  'plan': Plan(blog_title='Demystifying Self‑Attention: From Theory to Practice', audience='Developers and machine learning engineers interested in deep learning architectures', tone='Professional yet approachable, with concrete code snippets and actionable tips', blog_kind='explainer', constraints=[], tasks=[Task(id=1, title='Intuition Behind Self‑Attention', goal='Explain why self‑attention replaces recurrence and convolutions for sequence modeling.', bullets=['Describe the problem of fixed‑size receptive fields in RNNs/CNNs and how self‑attention provides a dynamic, content‑based receptive field.', 'Use a simple analogy (e.g., a word looking up related words in a dictionary) to convey the query‑key‑value concept.', 'Illustrate how every token can attend to every other token in a single layer, enabling long‑range dependencies.', 'Highlight the role of positional encodings in preserving order while using a permutation‑invariant mechanism.'], target_words=250, tags=['conceptual', 'motivation'], requires_research=False, requires_citations=False, requires_code=False), Task(id=2, title='Mathematical Formulation of Scaled Dot‑Product Attention', goal='Derive the core equations that define self‑attention and explain each term.', bullets=['Define query, key, and value matrices (Q, K, V) as linear projections of the input embeddings.', 'Show the dot‑product similarity step and the scaling factor 1/√d_k to stabilize gradients.', 'Explain the softmax normalization that produces attention weights and how they are applied to V.', 'Present the multi‑head extension, describing how multiple attention subspaces are concatenated.', 'Briefly discuss the computational complexity O(n²·d) versus O(n·d²) for RNNs.'], target_words=340, tags=['math', 'core'], requires_research=False, requires_citations=False, requires_code=False), Task(id=3, title='Implementing Self‑Attention from Scratch (PyTorch)', goal='Provide a minimal, runnable code sketch that builds a single‑head self‑attention module.', bullets=['Create linear layers for Q, K, V and initialize them with torch.nn.Linear.', 'Compute the scaled dot‑product, apply torch.nn.functional.softmax, and multiply by V.', 'Wrap the steps in a torch.nn.Module with a forward method that accepts a (batch, seq_len, d_model) tensor.', 'Verify shapes with assert statements and run a quick forward pass on random data.', 'Show how to stack the module into a tiny transformer encoder block.'], target_words=420, tags=['code', 'implementation'], requires_research=False, requires_citations=False, requires_code=True), Task(id=4, title='Edge Cases and Failure Modes', goal='Identify scenarios where self‑attention can break or produce sub‑optimal results.', bullets=['Explain the quadratic memory blow‑up for very long sequences and why padding can exacerbate it.', 'Discuss attention score saturation when queries and keys have large magnitudes, leading to near‑one‑hot distributions.', 'Show how improper positional encoding (or none at all) makes the model permutation‑invariant and loses order information.', 'Point out the risk of “attention drift” where a token attends to unrelated tokens due to noisy embeddings.', 'Mention numerical stability issues in the softmax (e.g., overflow) and the common trick of subtracting the max score.'], target_words=300, tags=['edge_cases', 'robustness'], requires_research=False, requires_citations=False, requires_code=False), Task(id=5, title='Performance and Cost Considerations', goal='Outline practical strategies to keep self‑attention efficient at scale.', bullets=['Compare full‑matrix attention with sparse / local attention variants (e.g., Longformer, BigBird) and their O(n·log\u202fn) or O(n) complexities.', 'Explain mixed‑precision (FP16/BF16) training to reduce memory bandwidth while preserving accuracy.', 'Show how to use flash‑attention kernels to cut both runtime and VRAM usage on modern GPUs.', 'Discuss the trade‑off between number of heads and per‑head dimension on throughput an ...
#  'as_of': '2026-02-09',
#  'recency_days': 3650,
#  'sections': [(1,
#    '## Intuition Behind Self‑Attention\n\n- **Fixed‑size receptive fields in RNNs/CNNs**  \n  Recurrent networks process tokens sequentially, so each hidden state can only incorporate information that has already been seen. Long‑range dependencies must travel through many time steps, which leads to vanishing gradients and slow training. Convolutional models use a sliding window whose size is set by the kernel and depth; even deep stacks only capture a limited context unless the network becomes very wide. In both cases the receptive field is static—it does not adapt to the actual content of the sequence.\n\n- **Dictionary analogy for query‑key‑value**  \n  Imagine a word as a curious reader that opens a dictionary. The *query* is the word itself, the *keys* are the dictionary entries (other words), and the *values* are the definitions. The reader scans the dictionary, finds entries whose keys match the query’s meaning, and then pulls the corresponding definitions. This content‑based lookup mirrors the query‑key‑value mechanism: each token generates a query vector, compares it to key vectors of all tokens, and retrieves a weighted sum of value vectors.\n\n- **All‑to‑all attention in a single layer**  \n  Because every query is compared against every key, a single self‑attention layer lets each token directly “look at” any other token, regardless of distance. The attention weights act as dynamic connections that can be strong for relevant words and near‑zero for irrelevant ones, enabling the model to capture long‑range relationships without stacking many layers.\n\n- **Positional encodings preserve order**  \n  Self‑attention itself is permutation‑invariant; swapping tokens would not change the computed queries, keys, and values. Positional encodings inject explicit position information into the token embeddings (e.g., sinusoidal or learned vectors) before the attention computation. This way the model knows that “the cat” appears before “sat” and can differentiate between “cat sat” and “sat cat” even though the attention mechanism treats the set of tokens as unordered.'),
#   (2,
#    '## Mathematical Formulation of Scaled Dot‑Product Attention\n\nSelf‑attention begins by turning a sequence of input embeddings \\(X \\in \\mathbb{R}^{n \\times d_{\\text{model}}}\\) into three separate representations: **queries**, **keys**, and **values**. Each is obtained via a learned linear projection:\n\n\\[\nQ = XW^{Q}, \\qquad\nK = XW^{K}, \\qquad\nV = XW^{V},\n\\]\n\nwhere \\(W^{Q}, W^{K}, W^{V} \\in \\mathbb{R}^{d_{\\text{model}} \\times d_k}\\) (or \\(d_v\\) for \\(V\\)). The matrices \\(Q, K, V \\in \\mathbb{R}^{n \\times d_k}\\) contain a row for every token, encoding how that token should **query** other tokens, how it should be **keyed**, and what **value** it contributes to the output.\n\nThe core similarity operation is a scaled dot‑product between queries and keys:\n\n\\[\n\\text{Scores} = \\frac{QK^{\\top}}{\\sqrt{d_k}}.\n\\]\n\nThe raw inner products \\(QK^{\\top}\\) grow with the dimensionality \\(d_k\\); dividing by \\(\\sqrt{d_k}\\) normalizes their magnitude, preventing the softmax (next step) from saturating and stabilizing gradient flow during training.\n\nThese scores are turned into a probability distribution over the sequence via a softmax applied row‑wise:\n\n\\[\nA = \\text{softmax}\\!\\left(\\frac{QK^{\\top}}{\\sqrt{d_k}}\\right) \\in \\mathbb{R}^{n \\times n}.\n\\]\n\nEach row \\(A_{i,:}\\) contains the attention weights that token \\(i\\) assigns to every other token. The final attended representation is a weighted sum of the values:\n\n\\[\n\\text{Attention}(Q,K,V) = AV.\n\\]\n\nThus, the output for token \\(i\\) is \\(\\sum_{j=1}^{n} A_{ij} V_{j}\\), mixing information from all positions according to learned relevance.\n\n**Multi‑head attention** extends this mechanism by projecting the inputs into \\(h\\) distinct subspaces, each with its own \\((Q_i, K_i, V_i)\\). The attention operation is performed in parallel:\n\n\\[\n\\text{head}_i = \\text{Attention}(Q_i, K_i, V_i), \\quad i = 1 \\dots h.\n\\]\n\nThe heads are then concatenated and linearly transformed:\n\n\\[\n\\text{MultiHead}(Q,K,V) = \\text{Concat}(\\text{head}_1,\\dots,\\text{head}_h)W^{O},\n\\]\n\nwhere \\(W^{O} \\in \\mathbb{R}^{hd_v \\times d_{\\text{model}}}\\). This design lets each head capture different relational patterns (e.g., syntax vs. semantics) while preserving the overall model dimension.\n\nFrom a computational standpoint, scaled dot‑product attention costs \\(O(n^{2}d_k)\\) because it forms an \\(n \\times n\\) similarity matrix. In contrast, a recurrent layer processes the sequence sequentially with cost \\(O(n d_{\\text{model}}^{2})\\). For long sequences, the quadratic term dominates, motivating recent efficient‑attention variants, but the parallel nature of self‑attention still offers significant speedups over the inherently sequential RNN computation.'),
#   (3,
#    '## Implementing Self‑Attention from Scratch (PyTorch)\n\nBelow is a compact, end‑to‑end implementation of a **single‑head** self‑attention layer. The code stays under 30 lines, can be dropped into any project, and demonstrates the core mathematics without the surrounding boilerplate of a full transformer.\n\n### 1. Linear projections for\u202fQ,\u202fK,\u202fV\n\n```python\nimport torch\nimport torch.nn as nn\nimport torch.nn.functional as F\n\nclass SelfAttention(nn.Module):\n    """Single‑head self‑attention."""\n    def __init__(self, d_model: int):\n        super().__init__()\n        # 1️⃣ Linear layers that map the input to queries, keys and values\n        self.q_proj = nn.Linear(d_model, d_model, bias=False)\n        self.k_proj = nn.Linear(d_model, d_model, bias=False)\n        self.v_proj = nn.Linear(d_model, d_model, bias=False)\n\n        # Optional scaling factor (√d_k) – computed once for efficiency\n        self.scale = d_model ** -0.5\n```\n\nThe three `nn.Linear` modules are instantiated with the same `d_model` (the hidden dimension of the model). No bias is needed because the subsequent softmax already normalises the scores.\n\n### 2. Scaled dot‑product, softmax, and value weighting\n\n```python\n    def forward(self, x: torch.Tensor) -> torch.Tensor:\n        """\n        x: (batch, seq_len, d_model)\n        returns: (batch, seq_len, d_model)\n        """\n        # 2️⃣ Project input to Q, K, V\n        Q = self.q_proj(x)          # (B, L, D)\n        K = self.k_proj(x)          # (B, L, D)\n        V = self.v_proj(x)          # (B, L, D)\n\n        # 3️⃣ Compute scaled dot‑product attention scores\n        #    (B, L, D) @ (B, D, L) -> (B, L, L)\n        scores = torch.matmul(Q, K.transpose(-2, -1)) * self.scale\n\n        # 4️⃣ Apply softmax across the key dimension\n        attn_weights = F.softmax(scores, dim=-1)   # (B, L, L)\n\n        # 5️⃣ Weighted sum of values\n        out = torch.matmul(attn_weights, V)        # (B, L, D)\n```\n\nThe scaling factor `√d_k` (implemented as `self.scale`) prevents the dot products from growing too large, which would push the softmax into regions with near‑zero gradients.\n\n### 3. Shape checks and a quick sanity run\n\n```python\n        # 6️⃣ Verify shapes – helpful during development\n        B, L, D = x.shape\n        assert Q.shape == (B, L, D)\n        assert K.shape == (B, L, D)\n        assert V.shape == (B, L, D)\n        assert attn_weights.shape == (B, L, L)\n        assert out.shape == (B, L, D)\n\n        return out\n```\n\nA minimal test confirms the module works as expected:\n\n```python\nif __name__ == "__main__":\n    batch, seq_len, d_model = 4, 10, 64\n    x = torch.randn(batch, seq_len, d_model)\n\n    attn = SelfAttention(d_model)\n    y = attn(x)                     # forward pass\n    print("Output shape:", y.shape)  # → torch.Size([4, 10, 64])\n```\n\nRunning this script prints `Output shape: torch.Size([4, 10, 64])`, showing that the layer preserves the input dimensionality while mixing information across the sequence.\n\n### 4. Stacking into a tiny Transformer encoder block\n\nA full encoder layer adds a **feed‑forward network** (FFN) and residual connections. Below is a stripped‑down version that re‑uses the `SelfAttention` module:\n\n```python\nclass TinyEncoderBlock(nn.Module):\n    def __init__(self, d_model: int, dim_feedforward: int = 128, dropout: float = 0.1):\n        super().__init__()\n        self.self_attn = SelfAttention(d_model)\n        self.norm1 = nn.LayerNorm(d_model)\n        self.norm2 = nn.LayerNorm(d_model)\n\n        self.ffn = nn.Sequential(\n            nn.Linear(d_model, dim_feedforward),\n            nn.ReLU(),\n            nn.Linear(dim_feedforward, d_model)\n        )\n        self.dropout = nn.Dropout(dropout)\n\n    def forward(self, x):\n        # Self‑attention + residual + norm\n        attn_out = self.self_attn(x)\n        x = self.norm1(x + self.dropout(attn_out))\n\n        # Feed‑forward + residual + ...
#   (4,
#    '## Edge Cases and Failure Modes\n\n**Quadratic memory blow‑up for very long sequences**  \nSelf‑attention computes a pairwise similarity matrix of size *N\u202f×\u202fN*, where *N* is the sequence length. Storing this matrix and the intermediate dot‑product results requires *O(N²)* memory. When *N* grows into the thousands, the memory consumption can exceed GPU limits. Padding aggravates the problem because many models still allocate the full *N\u202f×\u202fN* matrix even for padded positions, turning a modestly sized batch into a memory bottleneck.\n\n**Attention score saturation with large query/key magnitudes**  \nThe raw attention scores are the dot products of queries and keys, often scaled by 1/√d. If the vectors have unusually large magnitudes, the scores become large in absolute value. After the softmax, the distribution collapses to a near‑one‑hot pattern: one token receives almost the entire probability mass while the rest get negligible weight. This “saturation” reduces the model’s ability to blend information from multiple tokens and can destabilize training.\n\n**Improper or missing positional encoding**  \nSelf‑attention is inherently permutation‑invariant; without explicit position information, swapping two tokens leaves the attention computation unchanged. If positional encodings are omitted or poorly designed (e.g., using a constant vector), the model cannot distinguish order, causing it to treat sentences like “dog bites man” and “man bites dog” identically. Proper sinusoidal or learned encodings break this symmetry and preserve sequential structure.\n\n**Attention drift caused by noisy embeddings**  \nWhen input embeddings contain significant noise—perhaps due to insufficient pre‑training or domain shift—a token’s query may mistakenly align with unrelated keys. The attention map then “drifts,” allocating weight to semantically irrelevant tokens. This can propagate errors through subsequent layers, especially in deep transformers where each layer amplifies the mis‑aligned signals.\n\n**Numerical stability in the softmax**  \nThe softmax exponentiates the attention scores, which can overflow for large values, producing `inf` or `nan`. A standard remedy is to subtract the maximum score from each row before exponentiation:  \n\n```text\nscores = scores - max(scores, axis=-1, keepdims=True)\nweights = softmax(scores)\n```  \n\nThis shift does not change the resulting distribution but keeps the exponentials within a safe numeric range, preventing overflow and ensuring stable gradients.'),
#   (5,
#    '## Performance and Cost Considerations\n\n**Full‑matrix vs. sparse/local attention**  \nStandard self‑attention computes an \\(n \\times n\\) similarity matrix, giving a quadratic \\(\\mathcal{O}(n^2)\\) cost in both time and memory. For long sequences this quickly becomes prohibitive. Sparse variants such as Longformer and BigBird replace the dense matrix with a pattern of local windows and a small set of global tokens. Longformer’s sliding‑window attention scales as \\(\\mathcal{O}(n \\cdot w)\\) where \\(w\\) is the window size, often treated as \\(\\mathcal{O}(n)\\) when \\(w \\ll n\\). BigBird augments local windows with random and global attention, achieving an effective \\(\\mathcal{O}(n \\log n)\\) complexity. In practice, these methods reduce VRAM consumption by 2‑5× for sequences of length 4‑8\u202fk while preserving most of the representational power for tasks like document classification and long‑range language modeling.\n\n**Mixed‑precision training (FP16/BF16)**  \nTraining with half‑precision formats cuts the memory bandwidth per tensor by roughly half compared with FP32. FP16 (IEEE half) and BF16 (Brain Float) keep the same exponent range as FP32, so gradient scaling and loss‑scaling tricks are sufficient to avoid underflow. The result is a 30‑50\u202f% speedup on modern GPUs without measurable loss in final perplexity or downstream accuracy for most transformer sizes. Mixed‑precision also enables larger batch sizes or longer sequences within the same memory envelope, which directly translates to higher hardware utilization.\n\n**Flash‑attention kernels**  \nFlash‑attention rewrites the attention softmax to operate in a fused, cache‑aware fashion. By keeping the \\(QK^T\\) product and the subsequent softmax in on‑chip memory, it eliminates the need to materialize the full \\(n \\times n\\) matrix. Benchmarks on A100 and H100 GPUs show 2‑3× lower runtime and up to 40\u202f% VRAM savings for typical sequence lengths (e.g., 2\u202fk tokens). Integrating flash‑attention is as simple as swapping the standard `torch.nn.functional.scaled_dot_product_attention` call for the flash‑optimized version provided by libraries such as `xformers` or `flash-attn`.\n\n**Heads vs. per‑head dimension**  \nThe total hidden size \\(d_{\\text{model}}\\) is the product of the number of heads \\(h\\) and the per‑head dimension \\(d_k\\). Increasing \\(h\\) improves the model’s ability to attend to diverse subspaces but also raises the number of softmax operations and memory traffic. Conversely, larger \\(d_k\\) boosts per‑head expressiveness but can diminish parallelism because each head processes more data. Empirically, a balanced split (e.g., \\(h=12, d_k=64\\) for a 768‑dim model) offers the best throughput‑quality trade‑off. For very large models, reducing heads to 8–10 while expanding \\(d_k\\) to 96–128 can keep the compute density high on GPUs without a noticeable drop in accuracy.\n\n**Rule‑of‑thumb for sequence length vs. batch size**  \nGiven a fixed GPU memory budget \\(M\\), the dominant term is roughly \\(M \\approx B \\times n \\times d_{\\text{model}} \\times \\text{precision\\_factor}\\), where \\(B\\) is batch size, \\(n\\) sequence length, and the precision factor is 2 for FP16/BF16. A practical heuristic is:\n\n1. Allocate ~60\u202f% of \\(M\\) to the activation buffer (which scales with \\(B \\times n\\)).  \n2. Choose the largest \\(n\\) that keeps this buffer under the limit, then fill the remaining memory with \\(B\\).  \n\nIn concrete terms, on a 40\u202fGB A100 using FP16, a 768‑dim model can handle \\(n=2048\\) with \\(B=8\\) or \\(n=4096\\) with \\(B=2\\). If you need higher throughput, halve the sequence length and double the batch size; if you need longer context, reduce the batch size accordingly. This simple budgeting approach lets you experiment quickly without repeatedly profiling the full training loop.'),
#   (6,
#    '## Debugging and Observability Tips\n\n- **Log attention weight matrices and visualize them as heatmaps**  \n  The raw attention scores (`softmax(QKᵀ / √d)`) are dense tensors that reveal how the model distributes focus across tokens. Persist the weight matrix after each forward pass (e.g., `torch.save(attn_weights, path)`) and render it with a library like Matplotlib or Seaborn:\n\n  ```python\n  import seaborn as sns\n  sns.heatmap(attn_weights.squeeze().cpu(), cmap="viridis")\n  ```\n  A uniform heatmap often signals a scaling issue, while overly sharp peaks can indicate that the model is ignoring context. Comparing heatmaps across training epochs helps spot drift early.\n\n- **Use gradient‑checking (`torch.autograd.gradcheck`) on the attention module**  \n  Before integrating a custom attention implementation, run `gradcheck` to verify that the backward pass is numerically correct. This catches subtle bugs such as mismatched tensor shapes or incorrect data types (e.g., `float32` vs. `float64`). A typical invocation looks like:\n\n  ```python\n  from torch.autograd import gradcheck\n  inputs = (query.double(), key.double(), value.double())\n  test = gradcheck(custom_attention, inputs, eps=1e-6, atol=1e-4)\n  ```\n  If `gradcheck` fails, inspect the offending dimension and adjust the module’s reshaping logic.\n\n- **Instrument the forward pass with `torch.profiler`**  \n  Profiling reveals where compute time and FLOPs concentrate. Wrap the model’s inference loop:\n\n  ```python\n  with torch.profiler.profile(\n          activities=[torch.profiler.ProfilerActivity.CPU,\n                      torch.profiler.ProfilerActivity.CUDA],\n          record_shapes=True,\n          profile_memory=True) as prof:\n      output = model(input_ids)\n  print(prof.key_averages().table(sort_by="self_cpu_time_total"))\n  ```\n  Look for attention heads that dominate FLOPs; these are prime candidates for pruning or mixed‑precision optimization.\n\n- **Add unit tests that compare the custom implementation against `torch.nn.MultiheadAttention`**  \n  Generate synthetic inputs (e.g., random tensors with known sequence length and embedding size) and assert that both implementations produce numerically close outputs and gradients:\n\n  ```python\n  torch.testing.assert_allclose(custom_out, reference_out, atol=1e-5)\n  ```\n  Include edge cases such as varying batch sizes, padding masks, and causal masks to ensure robustness.\n\n- **Employ attention rollout or attribution methods (e.g., LRP) to verify token importance**  \n  Rollout aggregates attention across layers, yielding a single relevance map per input token. Implement the algorithm or use existing libraries to produce a relevance score vector, then overlay it on the original text. If high‑relevance tokens do not align with expected linguistic cues, revisit the attention scaling or positional encoding. Attribution techniques like Layer‑wise Relevance Propagation (LRP) provide a complementary, gradient‑based view, helping confirm that the model’s decisions are driven by the right parts of the sequence.')],
#  'final': '# Demystifying Self‑Attention: From Theory to Practice\n\n## Intuition Behind Self‑Attention\n\n- **Fixed‑size receptive fields in RNNs/CNNs**  \n  Recurrent networks process tokens sequentially, so each hidden state can only incorporate information that has already been seen. Long‑range dependencies must travel through many time steps, which leads to vanishing gradients and slow training. Convolutional models use a sliding window whose size is set by the kernel and depth; even deep stacks only capture a limited context unless the network becomes very wide. In both cases the receptive field is static—it does not adapt to the actual content of the sequence.\n\n- **Dictionary analogy for query‑key‑value**  \n  Imagine a word as a curious reader that opens a dictionary. The *query* is the word itself, the *keys* are the dictionary entries (other words), and the *values* are the definitions. The reader scans the dictionary, finds entries whose keys match the query’s meaning, and then pulls the corresponding definitions. This content‑based lookup mirrors the query‑key‑value mechanism: each token generates a query vector, compares it to key vectors of all tokens, and retrieves a weighted sum of value vectors.\n\n- **All‑to‑all attention in a single layer**  \n  Because every query is compared against every key, a single self‑attention layer lets each token directly “look at” any other token, regardless of distance. The attention weights act as dynamic connections that can be strong for relevant words and near‑zero for irrelevant ones, enabling the model to capture long‑range relationships without stacking many layers.\n\n- **Positional encodings preserve order**  \n  Self‑attention itself is permutation‑invariant; swapping tokens would not change the computed queries, keys, and values. Positional encodings inject explicit position information into the token embeddings (e.g., sinusoidal or learned vectors) before the attention computation. This way the model knows that “the cat” appears before “sat” and can differentiate between “cat sat” and “sat cat” even though the attention mechanism treats the set of tokens as unordered.\n\n## Mathematical Formulation of Scaled Dot‑Product Attention\n\nSelf‑attention begins by turning a sequence of input embeddings \\(X \\in \\mathbb{R}^{n \\times d_{\\text{model}}}\\) into three separate representations: **queries**, **keys**, and **values**. Each is obtained via a learned linear projection:\n\n\\[\nQ = XW^{Q}, \\qquad\nK = XW^{K}, \\qquad\nV = XW^{V},\n\\]\n\nwhere \\(W^{Q}, W^{K}, W^{V} \\in \\mathbb{R}^{d_{\\text{model}} \\times d_k}\\) (or \\(d_v\\) for \\(V\\)). The matrices \\(Q, K, V \\in \\mathbb{R}^{n \\times d_k}\\) contain a row for every token, encoding how that token should **query** other tokens, how it should be **keyed**, and what **value** it contributes to the output.\n\nThe core similarity operation is a scaled dot‑product between queries and keys:\n\n\\[\n\\text{Scores} = \\frac{QK^{\\top}}{\\sqrt{d_k}}.\n\\]\n\nThe raw inner products \\(QK^{\\top}\\) grow with the dimensionality \\(d_k\\); dividing by \\(\\sqrt{d_k}\\) normalizes their magnitude, preventing the softmax (next step) from saturating and stabilizing gradient flow during training.\n\nThese scores are turned into a probability distribution over the sequence via a softmax applied row‑wise:\n\n\\[\nA = \\text{softmax}\\!\\left(\\frac{QK^{\\top}}{\\sqrt{d_k}}\\right) \\in \\mathbb{R}^{n \\times n}.\n\\]\n\nEach row \\(A_{i,:}\\) contains the attention weights that token \\(i\\) assigns to every other token. The final attended representation is a weighted sum of the values:\n\n\\[\n\\text{Attention}(Q,K,V) = AV.\n\\]\n\nThus, the output for token \\(i\\) is \\(\\sum_{j=1}^{n} A_{ij} V_{j}\\), mixing information from all positions according to learned relevance.\n\n**Multi‑head attention** extends this mechanism by projecting the inputs into \\(h\\) distinct subspaces, each with its own \\((Q_i, K_i, V_i)\\ ...
